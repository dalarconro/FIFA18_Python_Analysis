# %% [markdown]
# # Data cleansing
#
# In this notebook we will cover the process of cleaning the data in different stages:
#
# 1. We will load the raw dataset of FIFA 18 players and check some of its properties.
#
# 2. We will filter the dataset to only use rows and columns of our interest.
#
# 3. We will transform required fields in order to perform a cleaner analysis.
#
# 4. We will deal with missing values, droping or filling them, whenever necessary.
#
# 5. We will save the processed dataset in a new folder.
#
# That way we will simulate an ETL process: Extract (step 1), Transform (steps 2, 3 and 4) and Load (step 5).
#
# We will be using functions defined in the script '../src/transfromations.py'. Also, alongside this notebook, we will be checking the effects of our transformations onto the dataset.

# %% [markdown]
# ## Step 1. Loading raw data.
#
# First step of our cleaning process is extracting the data from its source and import the necessary modules that we are going to use alongside this phase.

# %%
# These lines allow to check if transformation.py has changed before execute another cell
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

src_path = Path("..") / "src"
sys.path.append(str(src_path))

# %%
import pandas as pd
import transformations as tr

# %% [markdown]
# We read the csv file and show a few lines, info and description.

# %%
data = pd.read_csv('../data/raw/fifa.csv')

data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
#  13  Special                   18207 non-null  int64
#  14  Preferred Foot            18159 non-null  object
#  15  International Reputation  18159 non-null  float64
#  16  Weak Foot                 18159 non-null  float64
#  17  Skill Moves               18159 non-null  float64
#  18  Work Rate                 18159 non-null  object
#  19  Body Type                 18159 non-null  object
#  20  Real Face                 18159 non-null  object
#  21  Position                  18147 non-null  object
#  22  Jersey Number             18147 non-null  float64
#  23  Joined                    16654 non-null  object
#  24  Loaned From               1264 non-null   object
#  25  Contract Valid Until      17918 non-null  object
#  26  Height                    18159 non-null  object
#  27  Weight                    18159 non-null  object
#  28  LS                        16122 non-null  object
#  29  ST                        16122 non-null  object
#  30  RS                        16122 non-null  object
#  31  LW                        16122 non-null  object
#  32  LF                        16122 non-null  object
#  33  CF                        16122 non-null  object
#  34  RF                        16122 non-null  object
#  35  RW                        16122 non-null  object
#  36  LAM                       16122 non-null  object
#  37  CAM                       16122 non-null  object
#  38  RAM                       16122 non-null  object
#  39  LM                        16122 non-null  object
#  40  LCM                       16122 non-null  object
#  41  CM                        16122 non-null  object
#  42  RCM                       16122 non-null  object
#  43  RM                        16122 non-null  object
#  44  LWB                       16122 non-null  object
#  45  LDM                       16122 non-null  object
#  46  CDM                       16122 non-null  object
#  47  RDM                       16122 non-null  object
#  48  RWB                       16122 non-null  object
#  49  LB                        16122 non-null  object
#  50  LCB                       16122 non-null  object
#  51  CB                        16122 non-null  object
#  52  RCB                       16122 non-null  object
#  53  RB                        16122 non-null  object
#  54  Crossing                  18159 non-null  float64
#  55  Finishing                 18159 non-null  float64
#  56  HeadingAccuracy           18159 non-null  float64
#  57  ShortPassing              18159 non-null  float64
#  58  Volleys                   18159 non-null  float64
#  59  Dribbling                 18159 non-null  float64
#  60  Curve                     18159 non-null  float64
#  61  FKAccuracy                18159 non-null  float64
#  62  LongPassing               18159 non-null  float64
#  63  BallControl               18159 non-null  float64
#  64  Acceleration              18159 non-null  float64
#  65  SprintSpeed               18159 non-null  float64
#  66  Agility                   18159 non-null  float64
#  67  Reactions                 18159 non-null  float64
#  68  Balance                   18159 non-null  float64
#  69  ShotPower                 18159 non-null  float64
#  70  Jumping                   18159 non-null  float64
#  71  Stamina                   18159 non-null  float64
#  72  Strength                  18159 non-null  float64
#  73  LongShots                 18159 non-null  float64
#  74  Aggression                18159 non-null  float64
#  75  Interceptions             18159 non-null  float64
#  76  Positioning               18159 non-null  float64
#  77  Vision                    18159 non-null  float64
#  78  Penalties                 18159 non-null  float64
#  79  Composure                 18159 non-null  float64
#  80  Marking                   18159 non-null  float64
#  81  StandingTackle            18159 non-null  float64
#  82  SlidingTackle             18159 non-null  float64
#  83  GKDiving                  18159 non-null  float64
#  84  GKHandling                18159 non-null  float64
#  85  GKKicking                 18159 non-null  float64
#  86  GKPositioning             18159 non-null  float64
#  87  GKReflexes                18159 non-null  float64
#  88  Release Clause            16643 non-null  object
# dtypes: float64(38), int64(6), object(45)
# memory usage: 12.4+ MB

# %%
data.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# std      272.586016                  0.394031      0.660456      0.756164
# min      731.000000                  1.000000      1.000000      1.000000
# 25%     1457.000000                  1.000000      3.000000      2.000000
# 50%     1635.000000                  1.000000      3.000000      2.000000
# 75%     1787.000000                  1.000000      3.000000      3.000000
# max     2346.000000                  5.000000      5.000000      5.000000
#
#        Jersey Number  ...     Penalties     Composure       Marking  \
# count   18147.000000  ...  18159.000000  18159.000000  18159.000000
# mean       19.546096  ...     48.548598     58.648274     47.281623
# std        15.947765  ...     15.704053     11.436133     19.904397
# min         1.000000  ...      5.000000      3.000000      3.000000
# 25%         8.000000  ...     39.000000     51.000000     30.000000
# 50%        17.000000  ...     49.000000     60.000000     53.000000
# 75%        26.000000  ...     60.000000     67.000000     64.000000
# max        99.000000  ...     92.000000     96.000000     94.000000
#
#        StandingTackle  SlidingTackle      GKDiving    GKHandling  \
# count    18159.000000   18159.000000  18159.000000  18159.000000
# mean        47.697836      45.661435     16.616223     16.391596
# std         21.664004      21.289135     17.695349     16.906900
# min          2.000000       3.000000      1.000000      1.000000
# 25%         27.000000      24.000000      8.000000      8.000000
# 50%         55.000000      52.000000     11.000000     11.000000
# 75%         66.000000      64.000000     14.000000     14.000000
# max         93.000000      91.000000     90.000000     92.000000
#
#           GKKicking  GKPositioning    GKReflexes
# count  18159.000000   18159.000000  18159.000000
# mean      16.232061      16.388898     16.710887
# std       16.502864      17.034669     17.955119
# min        1.000000       1.000000      1.000000
# 25%        8.000000       8.000000      8.000000
# 50%       11.000000      11.000000     11.000000
# 75%       14.000000      14.000000     14.000000
# max       91.000000      90.000000     94.000000
#
# [8 rows x 44 columns]

# %% [markdown]
# We are not going to comment anything about the dataset, as it is already commented in the first notebook '01_exploration.ipynb'.

# %% [markdown]
# ## Step 2. Filtering the dataset.

# %% [markdown]
# Now we want to reduce our dataset selecting only relevant characteristic obout the players (column filtering). We will not make any row filtering to keep our complete data (we'll do it, if necessary, in the analysis phase).
#
# This logic is implemented in the transformation module function, 'filter'.

# %%
data_filtered = tr.filter(data)

data_filtered.head()
# Out:
#                 Name  Age Nationality  Overall  Potential    Value  \
# 0           L. Messi   31   Argentina       94         94  €110.5M
# 1  Cristiano Ronaldo   33    Portugal       94         94     €77M
# 2          Neymar Jr   26      Brazil       92         93  €118.5M
# 3             De Gea   27       Spain       91         93     €72M
# 4       K. De Bruyne   27     Belgium       91         92    €102M
#
#    International Reputation                 Club   Wage Preferred Foot  \
# 0                       5.0         FC Barcelona  €565K           Left
# 1                       5.0             Juventus  €405K          Right
# 2                       5.0  Paris Saint-Germain  €290K          Right
# 3                       4.0    Manchester United  €260K          Right
# 4                       4.0      Manchester City  €355K          Right
#
#    Weak Foot Position  Jersey Number Height  Weight        Joined  \
# 0        4.0       RF           10.0    5'7  159lbs   Jul 1, 2004
# 1        4.0       ST            7.0    6'2  183lbs  Jul 10, 2018
# 2        5.0       LW           10.0    5'9  150lbs   Aug 3, 2017
# 3        3.0       GK            1.0    6'4  168lbs   Jul 1, 2011
# 4        5.0      RCM            7.0   5'11  154lbs  Aug 30, 2015
#
#   Contract Valid Until Release Clause
# 0                 2021        €226.5M
# 1                 2022        €127.1M
# 2                 2022        €228.1M
# 3                 2020        €138.6M
# 4                 2023        €196.4M

# %% [markdown]
# Lets also look at some info and description about the new dataset.

# %%
data_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      18207 non-null  object
#  1   Age                       18207 non-null  int64
#  2   Nationality               18207 non-null  object
#  3   Overall                   18207 non-null  int64
#  4   Potential                 18207 non-null  int64
#  5   Value                     18207 non-null  object
#  6   International Reputation  18159 non-null  float64
#  7   Club                      17966 non-null  object
#  8   Wage                      18207 non-null  object
#  9   Preferred Foot            18159 non-null  object
#  10  Weak Foot                 18159 non-null  float64
#  11  Position                  18147 non-null  object
#  12  Jersey Number             18147 non-null  float64
#  13  Height                    18159 non-null  object
#  14  Weight                    18159 non-null  object
#  15  Joined                    16654 non-null  object
#  16  Contract Valid Until      17918 non-null  object
#  17  Release Clause            16643 non-null  object
# dtypes: float64(3), int64(3), object(12)
# memory usage: 2.5+ MB

# %%
data_filtered.describe()
# Out:
#                 Age       Overall     Potential  International Reputation  \
# count  18207.000000  18207.000000  18207.000000              18159.000000
# mean      25.122206     66.238699     71.307299                  1.113222
# std        4.669943      6.908930      6.136496                  0.394031
# min       16.000000     46.000000     48.000000                  1.000000
# 25%       21.000000     62.000000     67.000000                  1.000000
# 50%       25.000000     66.000000     71.000000                  1.000000
# 75%       28.000000     71.000000     75.000000                  1.000000
# max       45.000000     94.000000     95.000000                  5.000000
#
#           Weak Foot  Jersey Number
# count  18159.000000   18147.000000
# mean       2.947299      19.546096
# std        0.660456      15.947765
# min        1.000000       1.000000
# 25%        3.000000       8.000000
# 50%        3.000000      17.000000
# 75%        3.000000      26.000000
# max        5.000000      99.000000

# %% [markdown]
# Now we have a more readable dataset to work with.

# %% [markdown]
# ## Step 3. Transformations.

# %% [markdown]
# In this step we want to transform every column needed to perform a clean analysis and be able to deal with missing values. More accurately, we want to:
#
# 1. Convert 'Height' and 'Weight' columns to the International System units, and storing only the quantity (units will be specified in the column header).
#
# 2. Convert 'Value' 'Wage' and 'Release Clause' columns into numerical data (units will be specified in the column header).
#
# 3. Control that 'Joined' and 'Contract Valid Until' store valid and unified date formats.
#
# 4. Create tactical groups for the 'Position' column.
#
# 5. Make sure that the rest of numeric columns are numerical and not strings (age, overall, potential, international reputation, weak foot, and jersey number). This step will be done after dealing with missing values.
#
# First four steps are implemented by transformations function 'data_adjustment', which calls other transformation functions for each step.

# %%
data_transformed = tr.data_adjustment(data_filtered)

data_transformed.head()
# Out:
#                 Name  Age Nationality  Overall  Potential        Value  \
# 0           L. Messi   31   Argentina       94         94  110500000.0
# 1  Cristiano Ronaldo   33    Portugal       94         94   77000000.0
# 2          Neymar Jr   26      Brazil       92         93  118500000.0
# 3             De Gea   27       Spain       91         93   72000000.0
# 4       K. De Bruyne   27     Belgium       91         92  102000000.0
#
#    International Reputation                 Club      Wage Preferred Foot  \
# 0                       5.0         FC Barcelona  565000.0           Left
# 1                       5.0             Juventus  405000.0          Right
# 2                       5.0  Paris Saint-Germain  290000.0          Right
# 3                       4.0    Manchester United  260000.0          Right
# 4                       4.0      Manchester City  355000.0          Right
#
#    Weak Foot Position Position_Group  Jersey Number  Height  Weight  \
# 0        4.0       RF            ATT           10.0  170.18   72.12
# 1        4.0       ST            ATT            7.0  187.96   83.01
# 2        5.0       LW            ATT           10.0  175.26   68.04
# 3        3.0       GK             GK            1.0  193.04   76.20
# 4        5.0      RCM            MDF            7.0  180.34   69.85
#
#       Joined Contract Valid Until  Release Clause
# 0 2004-07-01           2021-12-31     226500000.0
# 1 2018-07-10           2022-12-31     127100000.0
# 2 2017-08-03           2022-12-31     228100000.0
# 3 2011-07-01           2020-12-31     138600000.0
# 4 2015-08-30           2023-12-31     196400000.0

# %%
data_transformed.describe()
# Out:
#                 Age       Overall     Potential         Value  \
# count  18207.000000  18207.000000  18207.000000  1.820700e+04
# mean      25.122206     66.238699     71.307299  2.410696e+06
# min       16.000000     46.000000     48.000000  0.000000e+00
# 25%       21.000000     62.000000     67.000000  3.000000e+05
# 50%       25.000000     66.000000     71.000000  6.750000e+05
# 75%       28.000000     71.000000     75.000000  2.000000e+06
# max       45.000000     94.000000     95.000000  1.185000e+08
# std        4.669943      6.908930      6.136496  5.594933e+06
#
#        International Reputation           Wage     Weak Foot  Jersey Number  \
# count              18159.000000   18207.000000  18159.000000   18147.000000
# mean                   1.113222    9731.312133      2.947299      19.546096
# min                    1.000000       0.000000      1.000000       1.000000
# 25%                    1.000000    1000.000000      3.000000       8.000000
# 50%                    1.000000    3000.000000      3.000000      17.000000
# 75%                    1.000000    9000.000000      3.000000      26.000000
# max                    5.000000  565000.000000      5.000000      99.000000
# std                    0.394031   21999.290406      0.660456      15.947765
#
#              Height        Weight                         Joined  \
# count  18159.000000  18159.000000                          16654
# mean     181.257584     75.286196  2016-11-15 10:04:54.848084736
# min      154.940000     49.900000            1991-06-01 00:00:00
# 25%      175.260000     69.850000            2016-05-23 06:00:00
# 50%      180.340000     74.840000            2017-07-03 00:00:00
# 75%      185.420000     79.830000            2018-07-01 00:00:00
# max      205.740000    110.220000            2018-12-20 00:00:00
# std        6.730145      7.073216                            NaN
#
#                 Contract Valid Until  Release Clause
# count                          17918    1.820700e+04
# mean   2021-02-09 16:17:39.225359872    4.191200e+06
# min              2018-11-30 00:00:00    0.000000e+00
# 25%              2019-12-31 00:00:00    3.920000e+05
# 50%              2020-12-31 00:00:00    1.000000e+06
# 75%              2021-12-31 00:00:00    3.000000e+06
# max              2026-12-31 00:00:00    2.281000e+08
# std                              NaN    1.070778e+07

# %%
data_transformed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      18207 non-null  object
#  1   Age                       18207 non-null  int64
#  2   Nationality               18207 non-null  object
#  3   Overall                   18207 non-null  int64
#  4   Potential                 18207 non-null  int64
#  5   Value                     18207 non-null  float64
#  6   International Reputation  18159 non-null  float64
#  7   Club                      17966 non-null  object
#  8   Wage                      18207 non-null  float64
#  9   Preferred Foot            18159 non-null  object
#  10  Weak Foot                 18159 non-null  float64
#  11  Position                  18147 non-null  object
#  12  Position_Group            18207 non-null  object
#  13  Jersey Number             18147 non-null  float64
#  14  Height                    18159 non-null  float64
#  15  Weight                    18159 non-null  float64
#  16  Joined                    16654 non-null  datetime64[ns]
#  17  Contract Valid Until      17918 non-null  datetime64[ns]
#  18  Release Clause            18207 non-null  float64
# dtypes: datetime64[ns](2), float64(8), int64(3), object(6)
# memory usage: 2.6+ MB

# %% [markdown]
# ## Step 4. Dealing with missing values.

# %% [markdown]
# We have implemented a function that drops or replaces missing values named missing_treatment for every column presented in the dataset. It performs the following actions depending on the column:
#
# * **Drop rows with missing values**: Name, Overall, Potential and Position.
#
# * **Value:** Replace missing values with 0.
#
# * **Age:** Replace missing malues with its mean.
#
# * **International Reputation:** Replace missing malues with its min value.
#
# * **Nationality:** Replace missing malues with 'Unknown'.
#
# * **Club:** Replace missing values with 'Free Agent'.
#
# * **Wage:** Replace missing malues with 0.
#
# * **Preferred Foot:** Replace missing values with 'Right'.
#
# * **Weak Foot:** Replace missing values with the minimum value in the dataset.
#
# * **Jersey Number:** Replace missing values with 0.
#
# * **Height:** Replace missing malues with its mean.
#
# * **Weight:** Replace missing malues with its mean.
#
# * **Joined:** Replace missing values with 'Jan 31, 2019' (virtually not joined yet, a free agent).
#
# * **Contract Valid Until:** Replace missing values with 'Dec 31, 2018' (current year).
#
# * **Release Clause:** Replace missing values with 0.

# %%
data_completed = tr.missing_treatment(data_transformed)

data_completed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18147 entries, 0 to 18206
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      18147 non-null  object
#  1   Age                       18147 non-null  int64
#  2   Nationality               18147 non-null  object
#  3   Overall                   18147 non-null  int64
#  4   Potential                 18147 non-null  int64
#  5   Value                     18147 non-null  float64
#  6   International Reputation  18147 non-null  float64
#  7   Club                      18147 non-null  object
#  8   Wage                      18147 non-null  float64
#  9   Preferred Foot            18147 non-null  object
#  10  Weak Foot                 18147 non-null  float64
#  11  Position                  18147 non-null  object
#  12  Position_Group            18147 non-null  object
#  13  Jersey Number             18147 non-null  float64
#  14  Height                    18147 non-null  float64
#  15  Weight                    18147 non-null  float64
#  16  Joined                    18147 non-null  datetime64[ns]
#  17  Contract Valid Until      18147 non-null  datetime64[ns]
#  18  Release Clause            18147 non-null  float64
# dtypes: datetime64[ns](2), float64(8), int64(3), object(6)
# memory usage: 2.8+ MB

# %% [markdown]
# ## Step 5. Final details

# %% [markdown]
# Now that we have filled all of the missing values, we only have to do the last few changes in order to improve our dataset presentation. These little changes are:
#
# 1. There are some float values (International Reputation, Weak Foot and Jersey Number) which should be ints. We will cast these columns into integers using the transformation function 'casting'.
#
# 2. We will scale currency columns making them more readable. 'Wage' column will be expressed in thousands of euros, while 'Value' and 'Release Clause' will be expressed in millions of euros. In addition, we will rename these columns to point out its scale (the same with 'Height' and Weight').

# %%
data_casted = tr.cast_to_integer(data_completed)
data_renamed = tr.scale_rename(data_casted)

# %% [markdown]
# And now we show the final DataFrame and some information about it.

# %%
data_renamed.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  Value (M_EUR)  \
# 0           L. Messi   31   Argentina       94         94          110.5
# 1  Cristiano Ronaldo   33    Portugal       94         94           77.0
# 2          Neymar Jr   26      Brazil       92         93          118.5
# 3             De Gea   27       Spain       91         93           72.0
# 4       K. De Bruyne   27     Belgium       91         92          102.0
#
#    International Reputation                 Club  Wage (K_EUR) Preferred Foot  \
# 0                         5         FC Barcelona         565.0           Left
# 1                         5             Juventus         405.0          Right
# 2                         5  Paris Saint-Germain         290.0          Right
# 3                         4    Manchester United         260.0          Right
# 4                         4      Manchester City         355.0          Right
#
#    Weak Foot Position Position_Group  Jersey Number  Height (cm)  Weight (kg)  \
# 0          4       RF            ATT             10       170.18        72.12
# 1          4       ST            ATT              7       187.96        83.01
# 2          5       LW            ATT             10       175.26        68.04
# 3          3       GK             GK              1       193.04        76.20
# 4          5      RCM            MDF              7       180.34        69.85
#
#       Joined Contract Valid Until  Release Clause (M_EUR)
# 0 2004-07-01           2021-12-31                   226.5
# 1 2018-07-10           2022-12-31                   127.1
# 2 2017-08-03           2022-12-31                   228.1
# 3 2011-07-01           2020-12-31                   138.6
# 4 2015-08-30           2023-12-31                   196.4

# %%
data_renamed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18147 entries, 0 to 18206
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      18147 non-null  object
#  1   Age                       18147 non-null  int64
#  2   Nationality               18147 non-null  object
#  3   Overall                   18147 non-null  int64
#  4   Potential                 18147 non-null  int64
#  5   Value (M_EUR)             18147 non-null  float64
#  6   International Reputation  18147 non-null  int64
#  7   Club                      18147 non-null  object
#  8   Wage (K_EUR)              18147 non-null  float64
#  9   Preferred Foot            18147 non-null  object
#  10  Weak Foot                 18147 non-null  int64
#  11  Position                  18147 non-null  object
#  12  Position_Group            18147 non-null  object
#  13  Jersey Number             18147 non-null  int64
#  14  Height (cm)               18147 non-null  float64
#  15  Weight (kg)               18147 non-null  float64
#  16  Joined                    18147 non-null  datetime64[ns]
#  17  Contract Valid Until      18147 non-null  datetime64[ns]
#  18  Release Clause (M_EUR)    18147 non-null  float64
# dtypes: datetime64[ns](2), float64(5), int64(6), object(6)
# memory usage: 2.8+ MB

# %%
data_renamed.describe()
# Out:
#                 Age       Overall     Potential  Value (M_EUR)  \
# count  18147.000000  18147.000000  18147.000000   18147.000000
# mean      25.121122     66.253926     71.324076       2.417729
# min       16.000000     46.000000     48.000000       0.000000
# 25%       21.000000     62.000000     67.000000       0.300000
# 50%       25.000000     66.000000     71.000000       0.675000
# 75%       28.000000     71.000000     75.000000       2.000000
# max       45.000000     94.000000     95.000000     118.500000
# std        4.669796      6.913320      6.132286       5.602826
#
#        International Reputation  Wage (K_EUR)     Weak Foot  Jersey Number  \
# count              18147.000000  18147.000000  18147.000000   18147.000000
# mean                   1.113297      9.759024      2.947154      19.546096
# min                    1.000000      0.000000      1.000000       1.000000
# 25%                    1.000000      1.000000      3.000000       8.000000
# 50%                    1.000000      3.000000      3.000000      17.000000
# 75%                    1.000000      9.000000      3.000000      26.000000
# max                    5.000000    565.000000      5.000000      99.000000
# std                    0.394150     22.030250      0.660498      15.947765
#
#         Height (cm)   Weight (kg)                         Joined  \
# count  18147.000000  18147.000000                          18147
# mean     181.259450     75.287940  2017-01-20 18:42:26.007604480
# min      154.940000     49.900000            1991-06-01 00:00:00
# 25%      175.260000     69.850000            2016-07-01 00:00:00
# 50%      180.340000     74.840000            2017-07-24 00:00:00
# 75%      185.420000     79.830000            2018-07-01 00:00:00
# max      205.740000    110.220000            2019-01-31 00:00:00
# std        6.730335      7.073234                            NaN
#
#                 Contract Valid Until  Release Clause (M_EUR)
# count                          18147            18147.000000
# mean   2021-01-30 22:35:00.843114496                4.205057
# min              2018-11-30 00:00:00                0.000000
# 25%              2019-12-31 00:00:00                0.398000
# 50%              2020-12-31 00:00:00                1.000000
# 75%              2021-12-31 00:00:00                3.000000
# max              2026-12-31 00:00:00              228.100000
# std                              NaN               10.722751

# %% [markdown]
# Now our dataset finally looks clean and ready for the analysis.

# %% [markdown]
# ## Step 6. Saving new dataset.

# %% [markdown]
# Last step is saving our dataset in '../data/processed/fifa_processed.csv'.

# %%
data_renamed.to_csv('../data/processed/fifa_processed.csv', index=False)
